# %% [markdown]
# ## Task 1
# Create a bar chart or histogram to visualize the distribution of a categorical or continuous variable, such as the distribution of ages or genders in a population.

# %% [markdown]
# ### Importing necessary libraries and data

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('insurance.csv')

# %%
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %% [markdown]
# ### Basic Checks

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
df.describe().T
# Out:
#            count          mean           std        min         25%       50%  \
# age       1338.0     39.207025     14.049960    18.0000    27.00000    39.000
# bmi       1338.0     30.663397      6.098187    15.9600    26.29625    30.400
# children  1338.0      1.094918      1.205493     0.0000     0.00000     1.000
# charges   1338.0  13270.422265  12110.011237  1121.8739  4740.28715  9382.033
#
#                    75%          max
# age          51.000000     64.00000
# bmi          34.693750     53.13000
# children      2.000000      5.00000
# charges   16639.912515  63770.42801

# %%
df.shape
# Out:
# (1338, 7)

# %%
df.nunique()
# Out:
# age           47
# sex            2
# bmi          548
# children       6
# smoker         2
# region         4
# charges     1337
# dtype: int64

# %% [markdown]
# ### Visualizations

# %% [markdown]
# #### Univariate

# %%
plt.hist(df['age'], bins=10, edgecolor='black', color='skyblue')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
df['sex'].value_counts().plot(kind='bar', color='salmon', edgecolor='black')
plt.title('Sex Distribution')
plt.xlabel('Sex')
plt.ylabel('Frequency')
plt.show()

# %%
df['smoker'].value_counts().plot(kind='bar', color='lightblue', edgecolor='black')
plt.title('Smoker Distribution')
plt.xlabel('Smoker')
plt.ylabel('Frequency')
plt.show()

# %%
plt.hist(df['bmi'], bins=10, edgecolor='black', color='lightcoral')
plt.title('BMI Distribution')
plt.xlabel('BMI')
plt.ylabel('Frequency')
plt.show()

# %%
plt.bar(df['children'].value_counts().index, df['children'].value_counts(), color='gold', edgecolor='black')
plt.title('Children Distribution')
plt.xlabel('Number of Children')
plt.ylabel('Frequency')
plt.show()

# %%
plt.hist(df['charges'], bins=10, edgecolor='black', color='lightgreen')
plt.title('Charges Distribution')
plt.xlabel('Charges')
plt.ylabel('Frequency')
plt.show()

# %%
plt.bar(df['region'].value_counts().index, df['region'].value_counts(),color='green',edgecolor='black')
plt.title('Region distribution')
plt.xlabel('Region')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# #### Bivariate

# %%
sns.scatterplot(data=df,x=df.bmi,y=df.charges,hue=df.sex)
# Out:
# <AxesSubplot:xlabel='bmi', ylabel='charges'>

# %%
plt.figure(figsize=(6, 4))
sns.boxplot(x='smoker', y='charges', data=df, palette='Set3')
plt.title('Box Plot for Smoker and Charges')
plt.xlabel('Smoker')
plt.ylabel('Charges')
plt.show()

# %%
corr_matrix = df[['age', 'bmi', 'charges']].corr()

# Heatmap for correlation
plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Heatmap for Correlation between Age, BMI, and Charges')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.swarmplot(x='children', y='charges', data=df, palette='Set2')
plt.title('Swarm Plot for Children and Charges')
plt.xlabel('Number of Children')
plt.ylabel('Charges')
plt.show()
# Out:
# U:\Users\UK\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 49.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# U:\Users\UK\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 34.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# U:\Users\UK\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 20.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# U:\Users\UK\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 7.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.pairplot(data=df)
